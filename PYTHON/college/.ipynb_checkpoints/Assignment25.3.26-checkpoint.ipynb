# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("company_sales_data.csv")
data
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
x=data['month_number']
y=data['total_profit']
plt.plot(x,y)
plt.title("Company profit per month")
plt.xlabel("Month Number")
plt.ylabel("Total profit")
plt.show()

# %%
x=data['month_number']
y=data['total_profit']
plt.plot(x,y,'--ro',mfc='black', linewidth=3)
plt.title("Company profit per month")
plt.xlabel("Month Number")
plt.ylabel("Total profit")
plt.legend('Profit data of last year')
plt.show()

# %%
face_cream=data['facecream']
face_wash=data['facewash']
tooth_paste=data['toothpaste']
bath_soap=data['bathingsoap']
shampoo=data['shampoo']
moisturizer=data['moisturizer']
months=data['month_number']
plt.plot(months,face_cream,'-ro', label='Face Cream')
plt.plot(months,face_wash,'-go', label='Face Wash')
plt.plot(months,tooth_paste,'-bo', label='Toothpaste')
plt.plot(months,bath_soap,'-mo', label='Bathing Soap')
plt.plot(months,shampoo,'-bo', label='Shampoo')
plt.plot(months,moisturizer,'-co', label='moisturizer')

plt.ylabel("Sales units in number")
plt.xlabel("Month Number")
plt.legend()
plt.show()

# %%
x=data['month_number']
y=data['toothpaste']
plt.scatter(x, y, label="Tooth paste Sales data")
plt.legend()
plt.title("Tooth paste Sales data")
plt.xlabel("Month number")
plt.ylabel("Number of units Sold")
plt.xticks(x,x)
plt.grid(linestyle="--")

# %%
x=data['month_number']
y1=data['facecream']
y2=data['facewash']
width=0.35
plt.bar(x-width/2,y1, width=width, label='face Cream sales data')
plt.bar(x+width/2,y2, width=width, label='Face wash sales data')
plt.legend()
plt.title("Facecream and facewash sales data")
plt.xlabel("Month Number")
plt.xticks(x,x)
plt.ylabel("Sales units in number")
plt.grid(linestyle="--")

# %%
x=data['month_number']
y=data['bathingsoap']
plt.bar(x, y)
plt.grid(linestyle="--")
plt.title("Bathing soap sales data")
plt.xlabel("Sales units in number")
plt.ylabel("Month Number")
plt.xticks(x,x)
plt.show()

# %%
facecream=data['facecream']
facewash=data['facewash']
toothpaste=data['toothpaste']
bathingsoap=data['bathingsoap']
shampoo=data['shampoo']
moisturizer=data['moisturizer']
labels=['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo', 'moisturizer']
values=[sum(facecream), sum(facewash), sum(toothpaste), sum(bathingsoap), sum(shampoo), sum(moisturizer)]
plt.figure(figsize=(10,10))
plt.pie(values, labels=labels, autopct='%1.1f%%')
plt.legend()
plt.show()

# %%
x=data['month_number']
y1=data['facewash']
y2=data['bathingsoap']
plt.subplot(2,1,1)
plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.plot(x, y1, '-ko',linewidth=2)
plt.ylabel("Sales units in number")
plt.title("Sales data of a facewash")
plt.subplot(2,1,2)
plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.plot(x, y2, '-ro', linewidth=2)
plt.xlabel("Month number")
plt.ylabel("Sales units in number")
plt.title("Sales data of a bathingsoap")
plt.show()
